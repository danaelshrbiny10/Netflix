# %%
import pandas as pd

# %%
data = pd.read_csv ('/content/titles.csv')
data
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm127384      Monty Python and the Holy Grail  MOVIE
# 3       tm70993                        Life of Brian  MOVIE
# 4      tm190788                         The Exorcist  MOVIE
# ...         ...                                  ...    ...
# 5801  tm1014599                            Fine Wine  MOVIE
# 5802  tm1108171                       Edis Starlight  MOVIE
# 5803  tm1045018                                Clash  MOVIE
# 5804  tm1098060                       Shadow Parties  MOVIE
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 2     King Arthur, accompanied by his squire, recrui...          1975
# 3     Brian Cohen is an average young Jewish man, bu...          1979
# 4     12-year-old Regan MacNeil begins to adapt an e...          1973
# ...                                                 ...           ...
# 5801  A beautiful love story that can happen between...          2021
# 5802  Rising star Edis's career journey with ups and...          2021
# 5803  A man from Nigeria returns to his family in Ca...          2021
# 5804  A family faces destruction in a long-running c...          2021
# 5805  With winter behind them, Bheem and his townspe...          2021
#
#      age_certification  runtime                             genres  \
# 0                TV-MA       48                  ['documentation']
# 1                    R      113                 ['crime', 'drama']
# 2                   PG       91              ['comedy', 'fantasy']
# 3                    R       94                         ['comedy']
# 4                    R      133                         ['horror']
# ...                ...      ...                                ...
# 5801               NaN      100               ['romance', 'drama']
# 5802               NaN       74         ['music', 'documentation']
# 5803               NaN       88                ['family', 'drama']
# 5804               NaN      116             ['action', 'thriller']
# 5805               NaN        0  ['family', 'comedy', 'animation']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                  ['US']      1.0         NaN         NaN         NaN
# 1                  ['US']      NaN   tt0075314         8.3    795222.0
# 2                  ['GB']      NaN   tt0071853         8.2    530877.0
# 3                  ['GB']      NaN   tt0079470         8.0    392419.0
# 4                  ['US']      NaN   tt0070047         8.1    391942.0
# ...                   ...      ...         ...         ...         ...
# 5801               ['NG']      NaN  tt13857480         6.9        39.0
# 5802                   []      NaN         NaN         NaN         NaN
# 5803         ['NG', 'CA']      NaN  tt14620732         6.5        32.0
# 5804                   []      NaN  tt10168094         6.2         9.0
# 5805                   []      1.0  tt13711094         8.8        16.0
#
#       tmdb_popularity  tmdb_score
# 0               0.600         NaN
# 1              27.612         8.2
# 2              18.216         7.8
# 3              17.505         7.8
# 4              95.337         7.7
# ...               ...         ...
# 5801            0.966         NaN
# 5802            1.036         8.5
# 5803            0.709         NaN
# 5804            2.186         NaN
# 5805            0.979        10.0
#
# [5806 rows x 15 columns]

# %%
df[['title','description']].head()
# Out:
#                                  title  \
# 0  Five Came Back: The Reference Films
# 1                          Taxi Driver
# 2      Monty Python and the Holy Grail
# 3                        Life of Brian
# 4                         The Exorcist
#
#                                          description
# 0  This collection includes 12 World War II-era p...
# 1  A mentally unstable Vietnam War veteran works ...
# 2  King Arthur, accompanied by his squire, recrui...
# 3  Brian Cohen is an average young Jewish man, bu...
# 4  12-year-old Regan MacNeil begins to adapt an e...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
netflix_data = df.copy()

# %%
tfidf = TfidfVectorizer(stop_words='english')
netflix_data['description'] = netflix_data['description'].fillna('')
tfidf_matrix = tfidf.fit_transform(netflix_data['description'])

# %%
from sklearn.metrics.pairwise import linear_kernel

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
indices = pd.Series(netflix_data.index, index=netflix_data['title']).drop_duplicates()

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]
    return netflix_data[['title','description']].iloc[movie_indices]

# %%
get_recommendations('Ganglands')
# Out:
#                                       title  \
# 715                                 Top Boy
# 3241                           Black Summer
# 3497        How to Sell Drugs Online (Fast)
# 2826                             Time Share
# 3220                                Top Boy
# 1617                  The Princess Weiyoung
# 5242                         Move to Heaven
# 5679  The Misadventures of Hedi and Cokeman
# 5093                          Gone for Good
# 2223                                   Dope
#
#                                             description
# 715   A thrilling and raw crime drama following a ga...
# 3241  In the dark, early days of a zombie apocalypse...
# 3497  How do you win back your girlfriend from the s...
# 2826  While staying at a tropical resort, a man beco...
# 3220  Two seasoned drug dealers return to the gritty...
# 1617  A princess descended from a ruined noble famil...
# 5242  Finding life in all that's left behind, a trau...
# 5679  In Paris, two dysfunctional dealers use family...
# 5093  Ten years ago, he lost two loved ones. When hi...
# 2223  Filmed from the perspectives of dealers, users...
